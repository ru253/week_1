# %% [markdown]
# <a href="https://colab.research.google.com/github/ru253/week_1/blob/main/pythonweek_1/python_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("rupa")
# Out:
# rupa
